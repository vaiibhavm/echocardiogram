# %% [markdown]
# # Echo Research Paper Kit - Kaggle Quickstart
# This notebook checks the environment, validates CAMUS, and starts one training run. Keep datasets private where required by their licenses.

# %%
# !nvidia-smi
import torch
print(torch.__version__, torch.cuda.is_available())
if torch.cuda.is_available(): print(torch.cuda.get_device_name(0))

# %%
# Change this path to where you copied/unzipped the project.
PROJECT='/kaggle/working/echo_research_paper_kit'
CAMUS='/kaggle/input/YOUR-CAMUS-DATASET'
# !pip install -q nibabel PyYAML
# !pip install -q -e {PROJECT}

# %%
# !python {PROJECT}/scripts/smoke_test.py
# !python {PROJECT}/scripts/check_dataset.py --config {PROJECT}/configs/proposed_binary.yaml --data-root {CAMUS}

# %%
# Start with one seed. Run the full five-seed matrix only after debugging and freezing the protocol.
# !python {PROJECT}/scripts/train.py --config {PROJECT}/configs/proposed_binary.yaml --data-root {CAMUS} --run-dir /kaggle/working/runs/proposed_seed2026 --seed 2026
